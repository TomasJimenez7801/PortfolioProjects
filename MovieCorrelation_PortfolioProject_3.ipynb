# %%
# Python Data Analysis Project 
""" 
skills used: statistical analysis, linear regressions, pipelines, importing data, cleaning data, 
formatting data types, visualizations 
"""


#Import libraries 

import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) #Adjusts the configuration of the plots

#Read in data

df = pd.read_csv(r'C:\Users\jimen\OneDrive\Escritorio\Portfolio Project 4 (Python Correlation)\movies.csv')

# %%
# Look at data
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Drop columns with missing data 
df = df.dropna()

# %%
# Validate there is no missing data
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{}-{}%'.format(col,pct_missing))
# Out:
# name-0.0%
# rating-0.0%
# genre-0.0%
# year-0.0%
# released-0.0%
# score-0.0%
# votes-0.0%
# director-0.0%
# writer-0.0%
# star-0.0%
# country-0.0%
# budget-0.0%
# gross-0.0%
# company-0.0%
# runtime-0.0%

# %%
# Check data types
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#Remove unnecessary decimals from columns 
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')
df['runtime'] = df['runtime'].astype('int64')
df['votes'] = df['votes'].astype('int64')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Create correct Year column
df['yearCorrect'] = df['released'].str.extract(pat = '([0-9]{4})').astype(int)

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Create a separate data frame with clean data
df1 = df.drop(columns=['released','year'])
df1.head()
# Out:
#                                              name rating      genre  score  \
# 0                                     The Shining      R      Drama    8.4
# 1                                 The Blue Lagoon      R  Adventure    5.8
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action    8.7
# 3                                       Airplane!     PG     Comedy    7.7
# 4                                      Caddyshack      R     Comedy    7.3
#
#      votes         director                   writer            star  \
# 0   927000  Stanley Kubrick             Stephen King  Jack Nicholson
# 1    65000   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields
# 2  1200000   Irvin Kershner           Leigh Brackett     Mark Hamill
# 3   221000     Jim Abrahams             Jim Abrahams     Robert Hays
# 4   108000     Harold Ramis       Brian Doyle-Murray     Chevy Chase
#
#           country    budget      gross             company  runtime  \
# ...

# %%
df1.sort_values(by=['gross'], inplace=False, ascending=False).head()
# Out:
#                                             name rating   genre  score  \
# 5445                                      Avatar  PG-13  Action    7.8
# 7445                           Avengers: Endgame  PG-13  Action    8.4
# 3045                                     Titanic  PG-13   Drama    7.8
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action    7.8
# 7244                      Avengers: Infinity War  PG-13  Action    8.4
#
#         votes       director              writer               star  \
# 5445  1100000  James Cameron       James Cameron    Sam Worthington
# 7445   903000  Anthony Russo  Christopher Markus  Robert Downey Jr.
# 3045  1100000  James Cameron       James Cameron  Leonardo DiCaprio
# 6663   876000    J.J. Abrams     Lawrence Kasdan       Daisy Ridley
# 7244   897000  Anthony Russo  Christopher Markus  Robert Downey Jr.
#
#             country     budget       gross                company  runtime  \
# ...

# %%
# Scatter plot with budget vs gross 

plt.scatter(x=df1['budget'], y=df1['gross'])

plt.title('Budget vs Gross Earnings')

plt.xlabel('Budget for Film')

plt.ylabel('Gross Earnings')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Create a regplot to evaluate the correlation

sns.regplot(x='budget', y='gross', data=df1, scatter_kws={'color':'red'}, line_kws={'color':'blue'})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
# Fit a linear regression model

X = df1[['budget']]
Y = df1['gross']
lr = LinearRegression()
lr.fit(X,Y)
lr.score(X,Y)
# Out:
# 0.5479649457884108

# %%
# An R^2 value of 0.5 indicates approximately 50% of the variation of gross earnings are explained by the simple linear model

# %%
df1[['budget','gross']].corr()
# Out:
#           budget     gross
# budget  1.000000  0.740247
# gross   0.740247  1.000000

# %%
correlation_matrix = df1.select_dtypes(include=['number']).corr()

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
# Find the correlation of gross, votes, year, budget vs score. Find whether funding, era, runtime and votes are
# responsible for a good/bad movie rating
df2 = df1[['gross','votes','yearCorrect','budget','score','runtime']]

# %%
X1 = df2[['gross','votes','yearCorrect','budget','runtime']]
Y1 = df2['score']
lr.fit(X1,Y1)
lr.score(X1,Y1)
# Out:
# 0.3393953727908273

# %%
# Create a pipeline object to predict the 'score', fitting the object with the X1 list and calculate the R^2.
from sklearn.metrics import mean_squared_error, r2_score

Input=[('scale',StandardScaler()),('polynomial', PolynomialFeatures(include_bias=False)),('model',LinearRegression())]
pipe = Pipeline(Input)
pipe.fit(X1,Y1)
yhat = pipe.predict(X1)
print(r2_score(Y1,yhat))
# Out:
# 0.4204075670618387

# %%
# Split the data into training and testing subsets and initialize a Ridge regressor and print the score for the testing data.

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.15, random_state=1)

RidgeModel = Ridge(alpha=0.1)
RidgeModel.fit(x_train,y_train)
Yhat = RidgeModel.predict(x_test)
print(r2_score(y_test,Yhat))
# Out:
# 0.5636285029773017

# %%
# Apply polynomial transformation to the training parameters and print the score for the testing subset.
pr = PolynomialFeatures(degree=3)
x_train_pr=pr.fit_transform(x_train)
x_test_pr=pr.fit_transform(x_test)
RidgeModel.fit(x_train_pr,y_train)
Yhat1 = RidgeModel.predict(x_test_pr)
print(r2_score(y_test,Yhat1))
# Out:
# 0.6012146656934503
# C:\Users\jimen\anaconda3\Lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.80662e-54): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T

# %%
"""
With this R^2 score we can say the model can predict with low-medium accuracy. We would want it
as close to 1 as possible 
"""
